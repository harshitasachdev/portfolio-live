# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Set the date range
start_date = "2014-01-01"
end_date = "2025-06-06"

# Download VIX and VVIX
tickers = ['^VIX', '^VVIX']
data = yf.download(tickers, start=start_date, end=end_date)['Close']

# Rename columns for clarity
data.columns = ['VIX', 'VVIX']

# Drop missing values
data.dropna(inplace=True)

# Preview data
print(data.tail())

# Optional: Save to CSV
data.to_csv("vix_vvix_data.csv")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  2 of 2 completed
#                   VIX       VVIX
# Date
# 2025-05-30  18.570000  95.150002
# 2025-06-02  18.360001  91.839996
# 2025-06-03  17.690001  90.889999
# 2025-06-04  17.610001  90.790001
# 2025-06-05  18.480000  93.199997

# %%
# Out:
# Requirement already satisfied: yfinance in c:\users\limfy\anaconda3\lib\site-packages (0.2.55)
# Collecting yfinance
#   Using cached yfinance-0.2.61-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\limfy\anaconda3\lib\site-packages (from yfinance) (3.20.3)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\limfy\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\limfy\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\limfy\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\limfy\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\limfy\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\limfy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\limfy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\limfy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: pycparser in c:\users\limfy\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\limfy\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Using cached yfinance-0.2.61-py2.py3-none-any.whl (117 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Installing collected packages: websockets, yfinance
#   Attempting uninstall: websockets
#     Found existing installation: websockets 10.4
#     Uninstalling websockets-10.4:
#       Successfully uninstalled websockets-10.4
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.55
#     Uninstalling yfinance-0.2.55:
#       Successfully uninstalled yfinance-0.2.55
# Successfully installed websockets-15.0.1 yfinance-0.2.61
# DEPRECATION: Loading egg at c:\users\limfy\anaconda3\lib\site-packages\jsonpointer-3.0.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# alpaca-trade-api 3.2.0 requires websockets<11,>=9.0, but you have websockets 15.0.1 which is incompatible.
# openbb-core 1.3.7 requires websockets<14.0,>=13.0, but you have websockets 15.0.1 which is incompatible.
